# %%
import matplotlib.pyplot as plt

# %%
# x-coordinates of left sides of bars  
left = [1, 2, 3] 
  
# heights of bars 
height = [28.96, 23.68, 34.21] 
  
# labels for bars 
tick_label = ['avg', 'variance', 'sobel'] 
  
# plotting a bar chart 
plt.bar(left, height, tick_label = tick_label, 
        width = 0.8, color = ['red', 'green', 'blue']) 
  
# naming the x-axis 
plt.xlabel('Type of image') 
# naming the y-axis 
plt.ylabel('% Accuracy') 
# plot title 
plt.title('DT depth = 6, data normalized') 
  
# function to show the plot 
plt.show()

# %%
# x-coordinates of left sides of bars  
left = [1, 2, 3] 
  
# heights of bars 
height = [34.21, 36.18, 18.42] 
  
# labels for bars 
tick_label = ['avg', 'variance', 'sobel'] 
  
# plotting a bar chart 
plt.bar(left, height, tick_label = tick_label, 
        width = 0.8, color = ['red', 'green', 'blue']) 
  
# naming the x-axis 
plt.xlabel('Type of image') 
# naming the y-axis 
plt.ylabel('% Accuracy') 
# plot title 
plt.title('DT depth = 6, data standardizated') 
  
# function to show the plot 
plt.show()

# %%
# x-coordinates of left sides of bars  
left = [1, 2, 3] 
  
# heights of bars 
height = [34.13, 34.88, 39.54] 
  
# labels for bars 
tick_label = ['avg-depth=2', 'variance-depth=1', 'sobel-depth=1'] 
  
# plotting a bar chart 
plt.bar(left, height, tick_label = tick_label, 
        width = 0.8, color = ['red', 'green', 'blue']) 
  
# naming the x-axis 
plt.xlabel('Type of image') 
# naming the y-axis 
plt.ylabel('% Accuracy') 
# plot title 
plt.title('DT change depth') 
  
# function to show the plot 
plt.show()
