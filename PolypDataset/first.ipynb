# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

path = '/home/estudiante/Documentos/PolypDataset/adenoma/'
vidcap = cv.VideoCapture(path+'NBI01.mp4')
#vidcap.set(cv.CAP_PROP_POS_FRAMES,0)
nun_frames = int(vidcap.get(cv.CAP_PROP_FRAME_COUNT))
chanels = 3
height = int(vidcap.get(cv.CAP_PROP_FRAME_HEIGHT))
width = int(vidcap.get(cv.CAP_PROP_FRAME_WIDTH))
success,image = vidcap.read()
image = np.array(image,np.float64)
plt.imshow(image)
#np_video = np.empty(shape = (height, width, nun_frames))
frame_sum = np.zeros(shape = (height, width, chanels))
count = 0
while success:
    
  #cv.imwrite("frame%d.jpg" % count, image)     # save frame as JPEG file   
    frame_sum = frame_sum + image
    #np_video[:,:,count] = image
    success,image = vidcap.read()
    image = np.array(image,np.float64)
    print('Read a new frame: ', success)
    count += 1
frame_avg = frame_sum/ count
#plt.imshow(frame_avg[:,:,::-1])
#plt.imshow((frame_avg[:,:,::-1] * 255).astype(np.uint8))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# ...
